# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
from xgboost import plot_importance
from xgboost import XGBClassifier

# %%
plt.rc('font', family='sans-serif')

# %%
data_set = pd.read_csv('credit_card_data.csv')
data_set.head()
# Out:
#   pop_cd  year  month  avg_score  avg_rat city  sex ages  population  \
# 0   L011  2016      1        812        2   서울  NaN  10대       55000
# 1   L011  2016      2        773        4   서울  NaN  10대      380000
# 2   L011  2016      3        771        4   서울  NaN  10대      387000
# 3   L011  2016      4        770        4   서울  NaN  10대      412000
# 4   L011  2016      5        771        4   서울  NaN  10대      414000
#
#    num_opencard  ...  monthly_installments_loan  monthly_insurance_loan  \
# 0          1.44  ...                          0                       0
# 1          1.71  ...                     510000                  220000
# 2          1.75  ...                     490000                  210000
# 3          1.76  ...                     510000                  240000
# 4          1.75  ...                     490000                  340000
#
#    monthly_sbk_loan  loan_commitment  inst_rep_loanb  ls_rep_loanb  \
# 0                 0          1120000         8210000      78020000
# 1           1020000           680000         4660000      23300000
# 2           1140000           640000         4370000      22930000
# 3           1340000           510000         4770000      22160000
# 4           1490000           640000         4740000      21960000
#
#    credit_loan  mortgage_loan  credit_card_payment  \
# 0     92170000       87260000                    0
# 1      8260000       42410000                 4000
# 2      8300000       41710000                 3000
# 3      9460000       41040000                 4000
# 4      9660000       40850000                 3000
#
#    credit_card_installments_payment
# 0                                 0
# 1                              1000
# 2                              1000
# 3                              1000
# 4                              1000
#
# [5 rows x 26 columns]

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3888 entries, 0 to 3887
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   pop_cd                            3888 non-null   object
#  1   year                              3888 non-null   int64
#  2   month                             3888 non-null   int64
#  3   avg_score                         3888 non-null   int64
#  4   avg_rat                           3888 non-null   int64
#  5   city                              3456 non-null   object
#  6   sex                               432 non-null    object
#  7   ages                              3888 non-null   object
#  8   population                        3888 non-null   int64
#  9   num_opencard                      3888 non-null   float64
#  10  num_usecard                       3888 non-null   float64
#  11  monthly_card_spend                3888 non-null   int64
#  12  monthly_lc                        3888 non-null   int64
#  13  monthly_loan                      3888 non-null   int64
#  14  monthly_bk_loan                   3888 non-null   int64
#  15  monthly_cd_loan                   3888 non-null   int64
#  16  monthly_installments_loan         3888 non-null   int64
#  17  monthly_insurance_loan            3888 non-null   int64
#  18  monthly_sbk_loan                  3888 non-null   int64
#  19  loan_commitment                   3888 non-null   int64
#  20  inst_rep_loanb                    3888 non-null   int64
#  21  ls_rep_loanb                      3888 non-null   int64
#  22  credit_loan                       3888 non-null   int64
#  23  mortgage_loan                     3888 non-null   int64
#  24  credit_card_payment               3888 non-null   int64
#  25  credit_card_installments_payment  3888 non-null   int64
# dtypes: float64(2), int64(20), object(4)
# memory usage: 789.9+ KB

# %%
data_set.columns
# Out:
# Index(['pop_cd', 'year', 'month', 'avg_score', 'avg_rat', 'city', 'sex',
#        'ages', 'population', 'num_opencard', 'num_usecard',
#        'monthly_card_spend', 'monthly_lc', 'monthly_loan', 'monthly_bk_loan',
#        'monthly_cd_loan', 'monthly_installments_loan',
#        'monthly_insurance_loan', 'monthly_sbk_loan', 'loan_commitment',
#        'inst_rep_loanb', 'ls_rep_loanb', 'credit_loan', 'mortgage_loan',
#        'credit_card_payment', 'credit_card_installments_payment'],
#       dtype='object')

# %%
drop_columns = ['year','pop_cd','city','sex','population','num_opencard']
data_set.drop(drop_columns,axis='columns',inplace=True)

# %%
data_set.head()
# Out:
#    month  avg_score  avg_rat ages  num_usecard  monthly_card_spend  \
# 0      1        812        2  10대         1.13               70000
# 1      2        773        4  10대         0.96              170000
# 2      3        771        4  10대         0.95              190000
# 3      4        770        4  10대         0.92              200000
# 4      5        771        4  10대         0.94              170000
#
#    monthly_lc  monthly_loan  monthly_bk_loan  monthly_cd_loan  \
# 0    92630000      87350000         85790000                0
# 1    31140000      28910000         25850000           190000
# 2    30230000      28180000         25110000           170000
# 3    30430000      27710000         24630000           190000
# 4    31210000      27620000         24390000           210000
#
#    monthly_installments_loan  monthly_insurance_loan  monthly_sbk_loan  \
# 0                          0                       0                 0
# 1                     510000                  220000           1020000
# 2                     490000                  210000           1140000
# 3                     510000                  240000           1340000
# 4                     490000                  340000           1490000
#
#    loan_commitment  inst_rep_loanb  ls_rep_loanb  credit_loan  mortgage_loan  \
# 0          1120000         8210000      78020000     92170000       87260000
# 1           680000         4660000      23300000      8260000       42410000
# 2           640000         4370000      22930000      8300000       41710000
# 3           510000         4770000      22160000      9460000       41040000
# 4           640000         4740000      21960000      9660000       40850000
#
#    credit_card_payment  credit_card_installments_payment
# 0                    0                                 0
# 1                 4000                              1000
# 2                 3000                              1000
# 3                 4000                              1000
# 4                 3000                              1000

# %%
data_set['ages'] = data_set['ages'].apply(lambda x:int(x[:-1])).astype(int)
data_set.head()
# Out:
#    month  avg_score  avg_rat  ages  num_usecard  monthly_card_spend  \
# 0      1        812        2    10         1.13               70000
# 1      2        773        4    10         0.96              170000
# 2      3        771        4    10         0.95              190000
# 3      4        770        4    10         0.92              200000
# 4      5        771        4    10         0.94              170000
#
#    monthly_lc  monthly_loan  monthly_bk_loan  monthly_cd_loan  \
# 0    92630000      87350000         85790000                0
# 1    31140000      28910000         25850000           190000
# 2    30230000      28180000         25110000           170000
# 3    30430000      27710000         24630000           190000
# 4    31210000      27620000         24390000           210000
#
#    monthly_installments_loan  monthly_insurance_loan  monthly_sbk_loan  \
# 0                          0                       0                 0
# 1                     510000                  220000           1020000
# 2                     490000                  210000           1140000
# 3                     510000                  240000           1340000
# 4                     490000                  340000           1490000
#
#    loan_commitment  inst_rep_loanb  ls_rep_loanb  credit_loan  mortgage_loan  \
# 0          1120000         8210000      78020000     92170000       87260000
# 1           680000         4660000      23300000      8260000       42410000
# 2           640000         4370000      22930000      8300000       41710000
# 3           510000         4770000      22160000      9460000       41040000
# 4           640000         4740000      21960000      9660000       40850000
#
#    credit_card_payment  credit_card_installments_payment
# 0                    0                                 0
# 1                 4000                              1000
# 2                 3000                              1000
# 3                 4000                              1000
# 4                 3000                              1000

# %%
data_set.shape
# Out:
# (3888, 20)

# %%
data_set.describe()
# Out:
#              month    avg_score      avg_rat        ages  num_usecard  \
# count  3888.000000  3888.000000  3888.000000  3888.00000  3888.000000
# mean      6.500000   801.297325     3.246914    50.00000     1.279462
# std       3.452497    22.924493     0.443042    25.82321     0.761102
# min       1.000000   726.000000     2.000000    10.00000     0.020000
# 25%       3.750000   783.000000     3.000000    30.00000     0.620000
# 50%       6.500000   808.000000     3.000000    50.00000     1.330000
# 75%       9.250000   819.000000     4.000000    70.00000     1.950000
# max      12.000000   850.000000     4.000000    90.00000     2.790000
#
#        monthly_card_spend    monthly_lc  monthly_loan  monthly_bk_loan  \
# count        3.888000e+03  3.888000e+03  3.888000e+03     3.888000e+03
# mean         8.232536e+05  7.005477e+07  5.993902e+07     4.549502e+07
# std          6.207234e+05  3.134869e+07  2.706806e+07     2.332790e+07
# min          2.000000e+04  3.500000e+06  3.500000e+06     1.210000e+06
# 25%          2.075000e+05  4.464000e+07  3.794250e+07     3.076250e+07
# 50%          7.500000e+05  7.597000e+07  6.477500e+07     4.786000e+07
# 75%          1.450000e+06  9.137500e+07  7.816000e+07     5.907000e+07
# max          2.300000e+06  1.817200e+08  1.658500e+08     1.506500e+08
#
#        monthly_cd_loan  monthly_installments_loan  monthly_insurance_loan  \
# count     3.888000e+03               3.888000e+03            3.888000e+03
# mean      6.917927e+05               2.401780e+06            1.674465e+06
# std       5.539698e+05               1.773271e+06            1.413189e+06
# min       0.000000e+00               0.000000e+00            0.000000e+00
# 25%       1.500000e+05               7.100000e+05            5.375000e+05
# 50%       6.500000e+05               2.290000e+06            1.230000e+06
# 75%       1.190000e+06               4.100000e+06            2.670000e+06
# max       2.040000e+06               5.960000e+06            6.980000e+06
#
#        monthly_sbk_loan  loan_commitment  inst_rep_loanb  ls_rep_loanb  \
# count      3.888000e+03     3.888000e+03    3.888000e+03  3.888000e+03
# mean       8.476929e+05     1.098907e+07    1.892440e+07  2.902791e+07
# std        7.746605e+05     6.303980e+06    1.102648e+07  1.561675e+07
# min        0.000000e+00     0.000000e+00    0.000000e+00  2.020000e+06
# 25%        2.100000e+05     6.197500e+06    9.747500e+06  1.886000e+07
# 50%        6.400000e+05     1.116000e+07    1.653500e+07  2.906000e+07
# 75%        1.350000e+06     1.579250e+07    2.645000e+07  3.741000e+07
# max        4.350000e+06     2.800000e+07    4.891000e+07  1.106000e+08
#
#         credit_loan  mortgage_loan  credit_card_payment  \
# count  3.888000e+03   3.888000e+03         3.888000e+03
# mean   1.993650e+07   7.703108e+07         4.199642e+05
# std    8.856546e+06   3.470092e+07         3.724923e+05
# min    0.000000e+00   3.500000e+06         0.000000e+00
# 25%    1.353000e+07   4.861750e+07         7.600000e+04
# 50%    1.860500e+07   8.112500e+07         2.790000e+05
# 75%    2.687000e+07   1.011700e+08         7.852500e+05
# max    9.217000e+07   1.830500e+08         1.367000e+06
#
#        credit_card_installments_payment
# count                       3888.000000
# mean                      141464.506173
# std                       115444.741416
# min                            0.000000
# 25%                        26750.000000
# 50%                       105000.000000
# 75%                       253000.000000
# max                       402000.000000

# %%
corr = data_set.corr()
f, ax = plt.subplots(figsize=(30, 8))

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

cmap = sns.diverging_palette(220, 20, sep=20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, vmin = -1,vmax = 1)

plt.show()

# %%
monthly_loan_set = ['monthly_bk_loan','monthly_cd_loan','monthly_installments_loan','monthly_insurance_loan','monthly_sbk_loan']

# %%
ages_unique_list = list(data_set.ages.unique())
ages_unique_list
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
loan_mean_list = list()
age_loan_dict = dict()
for age in list(data_set.ages.unique()):
    loan_mean = list()
    for loan in monthly_loan_set:
        loan_mean.append(data_set[data_set['ages']==age][loan].mean())
    loan_mean_list.append(loan_mean)

print(len(loan_mean_list))
loan_mean_list
# Out:
# 9
# [[7801643.518518519,
#   154490.74074074073,
#   1327430.5555555555,
#   342939.81481481483,
#   2183958.3333333335],
#  [18667615.740740743,
#   699907.4074074074,
#   3828472.222222222,
#   889537.0370370371,
#   1611458.3333333333],
#  [45782523.14814815,
#   1290254.6296296297,
#   4585532.407407408,
#   2778657.407407407,
#   1240717.5925925926],
#  [56857569.44444445,
#   1520324.0740740742,
#   4609328.703703703,
#   3726666.6666666665,
#   1038009.2592592592],
#  [61853009.25925926,
#   1206944.4444444445,
#   3664884.2592592593,
#   2908611.111111111,
#   672939.8148148148],
#  [57867592.59259259,
#   857962.9629629629,
#   2263935.185185185,
#   1832731.4814814816,
#   342175.9259259259],
#  [51444837.96296296,
#   355671.2962962963,
#   894513.8888888889,
#   1120949.0740740742,
#   199907.40740740742],
#  [52237013.88888889,
#   115000.0,
#   258495.37037037036,
#   1065856.4814814816,
#   163564.8148148148],
#  [56943356.481481485,
#   25578.703703703704,
#   183425.92592592593,
#   404236.1111111111,
#   176504.62962962964]]

# %%
colors = sns.color_palette('coolwarm_r',len(loan_mean_list))

# plt.subplots_adjust(wspace=1)
plt.figure(figsize=(15,15))
plt.subplots_adjust(wspace=0.1)
title_font = {
    'fontsize': 30,
}
for i in range(len(ages_unique_list)):
    plt.subplot(3,3,i+1)
    plt.pie(loan_mean_list[i],colors=colors)
    plt.title(f'{(i+1)*10}\'s',fontdict=title_font)

plt.show()

# %%
data_set.head()
# Out:
#    month  avg_score  avg_rat  ages  num_usecard  monthly_card_spend  \
# 0      1        812        2    10         1.13               70000
# 1      2        773        4    10         0.96              170000
# 2      3        771        4    10         0.95              190000
# 3      4        770        4    10         0.92              200000
# 4      5        771        4    10         0.94              170000
#
#    monthly_lc  monthly_loan  monthly_bk_loan  monthly_cd_loan  \
# 0    92630000      87350000         85790000                0
# 1    31140000      28910000         25850000           190000
# 2    30230000      28180000         25110000           170000
# 3    30430000      27710000         24630000           190000
# 4    31210000      27620000         24390000           210000
#
#    monthly_installments_loan  monthly_insurance_loan  monthly_sbk_loan  \
# 0                          0                       0                 0
# 1                     510000                  220000           1020000
# 2                     490000                  210000           1140000
# 3                     510000                  240000           1340000
# 4                     490000                  340000           1490000
#
#    loan_commitment  inst_rep_loanb  ls_rep_loanb  credit_loan  mortgage_loan  \
# 0          1120000         8210000      78020000     92170000       87260000
# 1           680000         4660000      23300000      8260000       42410000
# 2           640000         4370000      22930000      8300000       41710000
# 3           510000         4770000      22160000      9460000       41040000
# 4           640000         4740000      21960000      9660000       40850000
#
#    credit_card_payment  credit_card_installments_payment
# 0                    0                                 0
# 1                 4000                              1000
# 2                 3000                              1000
# 3                 4000                              1000
# 4                 3000                              1000

# %%
colors = sns.color_palette('coolwarm_r',len(loan_mean_list))

sns.set_palette(colors)
sns.set_style('whitegrid')
sns.set_style('ticks')
sns.relplot(x='ages',y='monthly_loan',data=data_set)

# %%
colors = sns.color_palette('coolwarm_r',len(loan_mean_list))
sns.set_palette(colors)

plt.scatter(data_set.ages,data_set.avg_rat,alpha=0.2,s=100*data_set.avg_rat)

# %%
colors = sns.color_palette('coolwarm_r',len(loan_mean_list))
sns.set_palette(colors)

plt.scatter(data_set.ages,data_set.avg_score,alpha=0.2)
plt.xlabel('ages')
plt.ylabel('avg_score')
# Out:
# Text(0, 0.5, 'avg_score')

# %%
colors = sns.color_palette('coolwarm_r',len(loan_mean_list))
sns.set_palette(colors)

sns.lineplot(x='ages',y='avg_score',ci="sd",data=data_set)
# Out:
# <AxesSubplot:xlabel='ages', ylabel='avg_score'>

# %%
under_30_data_set = data_set[(data_set['ages']==20) | (data_set['ages']==10)]

# %%
plt.scatter(under_30_data_set.num_usecard,under_30_data_set.monthly_card_spend)
plt.xlabel('1020-num_usecard', fontsize=10)
plt.ylabel('1020-monthly_card_spend', fontsize=10)
# Out:
# Text(0, 0.5, '1020-monthly_card_spend')

# %%
print(plt.rcParams['font.family'])
# Out:
# ['sans-serif']

# %%
colors = sns.color_palette('coolwarm_r',len(loan_mean_list))
sns.set_palette(colors)

sns.relplot(x='ages',y='avg_rat',data=data_set)

# %%
type(loan_mean_list[0])
# Out:
# list

# %%
# lc : 신용장

# %%
data_set.shape[1]
# Out:
# 20

# %%
data_set[data_set['ages']==20]['monthly_bk_loan'].mean()
# Out:
# 18667615.740740743

# %%
colors = sns.color_palette('coolwarm_r',len(loan_mean_list))
sns.set_palette(colors)

sns.lineplot(x='month',y='monthly_card_spend',data=under_30_data_set)
# Out:
# <AxesSubplot:xlabel='month', ylabel='monthly_card_spend'>

# %%
corr = under_30_data_set.corr()
f, ax = plt.subplots(figsize=(30, 8))

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

cmap = sns.diverging_palette(220, 20, sep=20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, vmin = -1,vmax = 1)

plt.show()

# %%
from sklearn.model_selection import train_test_split
from xgboost import plot_importance
from xgboost import XGBClassifier

# %%
y = data_set.avg_score
X = data_set.drop('avg_score',axis=1)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)
print(X_train.shape,X_test.shape)
# Out:
# (3110, 19) (778, 19)

# %%
xgb = XGBClassifier(n_estimators=100,learning_rate=0.1,max_depth=4)
xgb.fit(X_train,y_train)
pred_train = xgb.predict(X_train)
pred_test = xgb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
def print_metrics(y, pred):
    acc = accuracy_score(y, pred)
    recall = recall_score(y, pred, average='micro')
    precision = precision_score(y, pred, average='micro')
    f1 = f1_score(y, pred, average='micro')
    print(f'정확도:{acc}, 재현율(recall):{recall}, 정밀도(precision):{precision}, f1:{f1}')

# %%
print_metrics(y_test, pred_test)
# Out:
# 정확도:0.448586118251928, 재현율(recall):0.448586118251928, 정밀도(precision):0.448586118251928, f1:0.448586118251928

# %%
fig, ax = plt.subplots()
plot_importance(xgb,ax=ax,color='orangered')
plt.title('importance', fontsize = 15)
plt.yticks(fontsize = 10)
plt.ylabel('features', fontsize = 20)
# Out:
# Text(0, 0.5, 'features')

# %%
print_metrics(y_train, pred_train)
# Out:
# 정확도:0.9877813504823151, 재현율(recall):0.9877813504823151, 정밀도(precision):0.9877813504823151, f1:0.9877813504823151

# %%
data_set.head()
# Out:
#    month  avg_score  avg_rat  ages  num_usecard  monthly_card_spend  \
# 0      1        812        2    10         1.13               70000
# 1      2        773        4    10         0.96              170000
# 2      3        771        4    10         0.95              190000
# 3      4        770        4    10         0.92              200000
# 4      5        771        4    10         0.94              170000
#
#    monthly_lc  monthly_loan  monthly_bk_loan  monthly_cd_loan  \
# 0    92630000      87350000         85790000                0
# 1    31140000      28910000         25850000           190000
# 2    30230000      28180000         25110000           170000
# 3    30430000      27710000         24630000           190000
# 4    31210000      27620000         24390000           210000
#
#    monthly_installments_loan  monthly_insurance_loan  monthly_sbk_loan  \
# 0                          0                       0                 0
# 1                     510000                  220000           1020000
# 2                     490000                  210000           1140000
# 3                     510000                  240000           1340000
# 4                     490000                  340000           1490000
#
#    loan_commitment  inst_rep_loanb  ls_rep_loanb  credit_loan  mortgage_loan  \
# 0          1120000         8210000      78020000     92170000       87260000
# 1           680000         4660000      23300000      8260000       42410000
# 2           640000         4370000      22930000      8300000       41710000
# 3           510000         4770000      22160000      9460000       41040000
# 4           640000         4740000      21960000      9660000       40850000
#
#    credit_card_payment  credit_card_installments_payment
# 0                    0                                 0
# 1                 4000                              1000
# 2                 3000                              1000
# 3                 4000                              1000
# 4                 3000                              1000
